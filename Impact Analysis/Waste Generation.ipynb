# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
pd.set_option("display.max_columns",None)

# %%
WASTE_GENERATION_df = pd.read_csv("C:/Users/hp/Desktop/Projects/Business-Sustainability-through-Environmental-Impact-Analysis/Data/Waste Generation/municipal waste.csv")
WASTE_GENERATION_df.head()
# Out:
#            region               province                  name          tc  \
# 0  Emilia_Romagna                Ferrara             Comacchio  502.250000
# 1  Emilia_Romagna                Ferrara             Lagosanto  228.050003
# 2  Emilia_Romagna                Ferrara                  Goro  268.010010
# 3  Emilia_Romagna                Ferrara                Mesola  199.089996
# 4          Puglia  Barletta-Andria-Trani  Margherita di Savoia  233.639999
#
#          cres       csor   istat        area    pop  alt  isle  sea  \
# 0  129.270004  66.419998   38006  283.750000  22648  1.0   0.0  1.0
# 1   49.520000  44.139999   38011   34.439999   4952  1.0   0.0  1.0
# 2   50.610001  44.599998   38025   26.620001   3895  1.0   0.0  1.0
# 3   41.110001  40.439999   38014   84.300003   7140  1.0   0.0  1.0
# 4   58.270000  25.950001  110005   35.700001  12193  1.0   0.0  1.0
#
#          pden           wden  urb       fee  d_fee  sample    organic  \
# ...

# %%
categorical_columns = ["region","province","name","istat","alt","isle","sea","urb","fee","d_fee","sample","geo","s_wteregio","s_landfill"]

# %%
WASTE_GENERATION_df.shape
# Out:
# (4341, 39)

# %%
numerical_df = WASTE_GENERATION_df.drop(categorical_columns,axis=1)
numerical_df.head()
# Out:
#            tc        cres       csor        area    pop        pden  \
# 0  502.250000  129.270004  66.419998  283.750000  22648   79.816742
# 1  228.050003   49.520000  44.139999   34.439999   4952  143.786301
# 2  268.010010   50.610001  44.599998   26.620001   3895  146.318558
# 3  199.089996   41.110001  40.439999   84.300003   7140   84.697502
# 4  233.639999   58.270000  25.950001   35.700001  12193  341.540619
#
#             wden    organic      paper     glass      wood     metal  \
# 0  119671.476562        NaN   4.363508  3.592508  2.269844  0.462317
# 1   70030.984375  35.040904   9.887817  9.518352  4.001796  1.860965
# 2   81116.523438  37.377010  11.991079  6.653014  0.000013  0.744725
# 3   43320.460938  45.310474   9.762878  7.551381  0.148580  0.746540
# 4  201565.265625   0.428440   6.601569  4.334883  2.296731  0.103101
#
#     plastic      raee    texile      other      msw_so    msw_un       msw  \
# ...

# %%
numerical_df.isnull().sum()
# Out:
# tc            0
# cres         52
# csor         67
# area          6
# pop           0
# pden          6
# wden          6
# organic     512
# paper        25
# glass        33
# wood       1095
# metal       246
# plastic      39
# raee        314
# texile     1013
# other       136
# msw_so        0
# msw_un        0
# msw           0
# sor           0
# roads       443
# gdp         386
# proads      443
# wage        285
# finance     386
# dtype: int64

# %%
for col in numerical_df.columns:
    numerical_df[col].fillna(numerical_df[col].mean(),inplace=True)

# %%
numerical_df.isnull().sum()
# Out:
# tc         0
# cres       0
# csor       0
# area       0
# pop        0
# pden       0
# wden       0
# organic    0
# paper      0
# glass      0
# wood       0
# metal      0
# plastic    0
# raee       0
# texile     0
# other      0
# msw_so     0
# msw_un     0
# msw        0
# sor        0
# roads      0
# gdp        0
# proads     0
# wage       0
# finance    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
round(numerical_df["tc"].sum()) #Total cost per captia spend in managing the waste
# Out:
# 669537

# %%
round(numerical_df["cres"].sum()) #Total money saved
# Out:
# 235195

# %%
round(numerical_df["pden"].mean()) # Average people per km2
# Out:
# 405

# %%
round(numerical_df["wden"].mean()) # Average Waste per km2
# Out:
# 192058

# %%
plt.figure(figsize=(7,7))
data = numerical_df[["organic","paper","glass","wood","metal","plastic","raee","texile","other"]].describe().loc["mean"]
palette_color = sns.color_palette('bright')
plt.pie(data,labels = data.index,colors=palette_color,autopct='%.0f%%',)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e193524370>,
# ...
#  [Text(0.514710147709396, 0.9721488897514475, 'organic'),
#   Text(-0.9949855931910055, 0.4690454874981135, 'paper'),
#   Text(-0.9374626258570158, -0.5754683528407701, 'glass'),
#   Text(-0.3899603398384815, -1.0285576956851066, 'wood'),
#   Text(-0.08394027918026281, -1.096792610082298, 'metal'),
#   Text(0.332289407512281, -1.048610389827956, 'plastic'),
#   Text(0.6781430849768917, -0.8660958124237897, 'raee'),
#   Text(0.7587042238834968, -0.7964721593761711, 'texile'),
#   Text(1.0188898933945818, -0.41456409050758103, 'other')],
#  [Text(0.28075098965967055, 0.5302630307735168, '35%'),
#   Text(-0.5427194144678211, 0.2558429931807891, '17%'),
#   Text(-0.5113432504674631, -0.31389182882223826, '15%'),
#   Text(-0.21270563991189897, -0.5610314703736944, '6%'),
#   Text(-0.04578560682559789, -0.5982505145903443, '3%'),
#   Text(0.18124876773397144, -0.5719693035425213, '9%'),
# ...

# %%
plt.figure(figsize=(7,7))
data = numerical_df[["msw_so","msw_un"]].describe().loc["mean"]
palette_color = sns.color_palette('bright')
plt.pie(data,colors=palette_color,autopct='%.0f%%',labels=["sorted waste","unsorted waste"],)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e1957584c0>,
# ...
#  [Text(-0.38549233289641804, 1.0302405841734625, 'sorted waste'),
#   Text(0.38549252581258103, -1.0302405119886504, 'unsorted waste')],
#  [Text(-0.210268545216228, 0.5619494095491614, '61%'),
#   Text(0.21026865044322599, -0.5619493701756274, '39%')])

# %%
WASTE_GENERATION_df.head()
# Out:
#            tc        cres       csor   istat        area    pop  alt  isle  \
# 0  502.250000  129.270004  66.419998   38006  283.750000  22648  1.0   0.0
# 1  228.050003   49.520000  44.139999   38011   34.439999   4952  1.0   0.0
# 2  268.010010   50.610001  44.599998   38025   26.620001   3895  1.0   0.0
# 3  199.089996   41.110001  40.439999   38014   84.300003   7140  1.0   0.0
# 4  233.639999   58.270000  25.950001  110005   35.700001  12193  1.0   0.0
#
#    sea        pden           wden  urb  d_fee  sample    organic      paper  \
# 0  1.0   79.816742  119671.476562  2.0      1       1        NaN   4.363508
# 1  1.0  143.786301   70030.984375  3.0      1       1  35.040904   9.887817
# 2  1.0  146.318558   81116.523438  3.0      1       1  37.377010  11.991079
# 3  1.0   84.697502   43320.460938  3.0      1       1  45.310474   9.762878
# 4  1.0  341.540619  201565.265625  2.0      0       0   0.428440   6.601569
#
# ...
