# %%
import pandas as pd
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9180\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_excel('Data/IWA-Environmental-Dataset-Final-Sample-External.xlsx',sheet_name='Final Raw Sample(0%)')
df.head()
# Out:
#    Year        Company Name  \
# 0  2019            SAGA PLC
# 1  2019  BURSA MALAYSIA BHD
# 2  2019  INTERTEK GROUP PLC
# 3  2019         JSE LIMITED
# 4  2019   BUREAU VERITAS SA
#
#                                              Country  \
# 0  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 1                                           MALAYSIA
# 2  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 3                                       SOUTH AFRICA
# 4                                             FRANCE
#
#                 GICS Sub-Industry  \
# 0            Multi-line Insurance
# 1      Financial Exchanges & Data
# 2  Research & Consulting Services
# 3      Financial Exchanges & Data
# 4  Research & Consulting Services
#
#                                  Industry (Exiobase)  \
# 0  Activities auxiliary to financial intermediati...
# 1  Activities auxiliary to financial intermediati...
# 2  Activities auxiliary to financial intermediati...
# ...

# %%
df.shape
# Out:
# (14035, 34)

# %%
df.isnull().mean()*100
# Out:
# Year                                                             0.000000
# Company Name                                                     0.000000
# Country                                                          0.149626
# GICS Sub-Industry                                                0.000000
# Industry (Exiobase)                                              0.000000
# Environmental Intensity (Sales)                                  0.000000
# Environmental Intensity (Op Inc)                                 5.429284
# Total Environmental Cost                                         0.000000
# Working Capacity                                                 0.000000
# Fish Production Capacity                                         0.000000
# Crop Production Capacity                                         0.000000
# Meat Production Capacity                                         0.000000
# Biodiversity                                                     0.000000
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Year                                                             0
# Company Name                                                     0
# Country                                                          0
# GICS Sub-Industry                                                0
# Industry (Exiobase)                                              0
# Environmental Intensity (Sales)                                  0
# Environmental Intensity (Op Inc)                                 0
# Total Environmental Cost                                         0
# Working Capacity                                                 0
# Fish Production Capacity                                         0
# Crop Production Capacity                                         0
# Meat Production Capacity                                         0
# Biodiversity                                                     0
# Abiotic Resources                                                0
# ...
